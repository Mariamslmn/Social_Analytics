# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import time
from matplotlib import style
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#BBC 
# Target Account
target_user_BBC = "BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_BBC = []

# Variable for max_id
oldest_tweet_BBC = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets_BBC = api.user_timeline(target_user_BBC, max_id = oldest_tweet_BBC)

    # Loop through all tweets 
    for tweet in public_tweets_BBC:

        # Print Tweets
        # print("Tweet {counter}: {tweet["text"]})
        
        # Run Vader Analysis on each tweet
        results_BBC = analyzer.polarity_scores(tweet["text"])
        compound = results_BBC["compound"]
        pos = results_BBC["pos"]
        neu = results_BBC["neu"]
        neg = results_BBC["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_BBC.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1
        
        
# Convert sentiments to DataFrame
sentiments_BBC_pd = pd.DataFrame.from_dict(sentiments_BBC)
sentiments_BBC_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Jul 14 19:03:07 +0000 2018     1.000    0.000     0.000
# 1    0.3818  Sat Jul 14 18:03:04 +0000 2018     0.843    0.000     0.157
# 2    0.8271  Sat Jul 14 17:32:50 +0000 2018     0.609    0.000     0.391
# 3    0.6688  Sat Jul 14 16:23:10 +0000 2018     0.824    0.000     0.176
# 4    0.2714  Sat Jul 14 16:03:05 +0000 2018     0.621    0.147     0.232
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot for BBC
x_vals_BBC = sentiments_BBC_pd["Tweets Ago"]
y_vals_BBC = sentiments_BBC_pd["Compound"]

# %%
#NYTimes
# Target Account
target_user_NT = "nytimes"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_NT = []

# Variable for max_id
oldest_tweet_NT = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets_NT = api.user_timeline(target_user_NT, max_id = oldest_tweet_NT)

    # Loop through all tweets 
    for tweet in public_tweets_NT:

        # Print Tweets
        # print("Tweet {counter}: {tweet["text"]})
        
        # Run Vader Analysis on each tweet
        results_NT = analyzer.polarity_scores(tweet["text"])
        compound = results_NT["compound"]
        pos = results_NT["pos"]
        neu = results_NT["neu"]
        neg = results_NT["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet_NT = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_NT.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1
        
# Convert sentiments to DataFrame
sentiments_NT_pd = pd.DataFrame.from_dict(sentiments_NT)
sentiments_NT_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.3804  Sat Jul 14 22:17:48 +0000 2018     0.715    0.178     0.107
# 1    0.0000  Sat Jul 14 22:00:06 +0000 2018     1.000    0.000     0.000
# 2    0.0000  Sat Jul 14 21:45:06 +0000 2018     1.000    0.000     0.000
# 3   -0.6249  Sat Jul 14 21:30:09 +0000 2018     0.745    0.255     0.000
# 4    0.0000  Sat Jul 14 21:22:04 +0000 2018     1.000    0.000     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot FOR Newyork Times
x_vals_NT = sentiments_NT_pd["Tweets Ago"]
y_vals_NT = sentiments_NT_pd["Compound"]

# %%
#CBS
# Target Account
target_user_CBS= "CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_CBS = []

# Variable for max_id
oldest_tweet_CBS = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets_CBS = api.user_timeline(target_user_CBS, max_id = oldest_tweet_CBS)

    # Loop through all tweets 
    for tweet in public_tweets_CBS:

        # Print Tweets
        # print("Tweet {counter}: {tweet["text"]})
        
        # Run Vader Analysis on each tweet
        results_CBS = analyzer.polarity_scores(tweet["text"])
        compound = results_CBS["compound"]
        pos = results_CBS["pos"]
        neu = results_CBS["neu"]
        neg = results_CBS["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet_CBS = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_CBS.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1
        
# Convert sentiments to DataFrame
sentiments_CBS_pd = pd.DataFrame.from_dict(sentiments_CBS)
sentiments_CBS_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.1139  Fri Jul 13 21:35:01 +0000 2018     0.922    0.000     0.078
# 1   -0.4404  Fri Jul 13 21:15:41 +0000 2018     0.868    0.132     0.000
# 2    0.0000  Fri Jul 13 17:49:38 +0000 2018     1.000    0.000     0.000
# 3    0.6514  Thu Jul 12 01:01:24 +0000 2018     0.718    0.000     0.282
# 4    0.5562  Wed Jul 11 21:44:45 +0000 2018     0.826    0.000     0.174
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot FOR CBS
x_vals_CBS = sentiments_CBS_pd["Tweets Ago"]
y_vals_CBS = sentiments_CBS_pd["Compound"]

# %%
#CNN
# Target Account
target_user_CNN= "CNN"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_CNN = []

# Variable for max_id
oldest_tweet_CNN = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets_CNN = api.user_timeline(target_user_CNN, max_id = oldest_tweet_CNN)

    # Loop through all tweets 
    for tweet in public_tweets_CNN:

        # Print Tweets
        # print("Tweet {counter}: {tweet["text"]})
        
        # Run Vader Analysis on each tweet
        results_CNN = analyzer.polarity_scores(tweet["text"])
        compound = results_CNN["compound"]
        pos = results_CNN["pos"]
        neu = results_CNN["neu"]
        neg = results_CNN["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet_CNN = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_CNN.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1
        
# Convert sentiments to DataFrame
sentiments_CNN_pd = pd.DataFrame.from_dict(sentiments_CNN)
sentiments_CNN_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.7964  Sat Jul 14 22:15:57 +0000 2018     0.649    0.351     0.000
# 1   -0.1779  Sat Jul 14 22:00:27 +0000 2018     0.773    0.130     0.097
# 2   -0.4939  Sat Jul 14 21:45:05 +0000 2018     0.833    0.167     0.000
# 3    0.0000  Sat Jul 14 21:30:12 +0000 2018     1.000    0.000     0.000
# 4    0.0000  Sat Jul 14 21:15:04 +0000 2018     1.000    0.000     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot FOR CNN
x_vals_CNN = sentiments_CNN_pd["Tweets Ago"]
y_vals_CNN = sentiments_CNN_pd["Compound"]

# %%
#FoxNews 
# Target Account
target_user_Fox= "FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments_Fox = []

# Variable for max_id
oldest_tweet_Fox = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets_Fox = api.user_timeline(target_user_Fox, max_id = oldest_tweet_Fox)

    # Loop through all tweets 
    for tweet in public_tweets_Fox:

        # Print Tweets
        # print("Tweet {counter}: {tweet["text"]})
        
        # Run Vader Analysis on each tweet
        results_Fox = analyzer.polarity_scores(tweet["text"])
        compound = results_Fox["compound"]
        pos = results_Fox["pos"]
        neu = results_Fox["neu"]
        neg = results_Fox["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet_Fox = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments_Fox.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1
        
# Convert sentiments to DataFrame
sentiments_Fox_pd = pd.DataFrame.from_dict(sentiments_Fox)
sentiments_Fox_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.2023  Sat Jul 14 22:25:16 +0000 2018     0.776    0.095     0.129
# 1    0.4767  Sat Jul 14 22:19:37 +0000 2018     0.662    0.099     0.238
# 2   -0.4939  Sat Jul 14 22:09:26 +0000 2018     0.704    0.296     0.000
# 3    0.6486  Sat Jul 14 21:57:34 +0000 2018     0.725    0.000     0.275
# 4    0.1280  Sat Jul 14 21:49:00 +0000 2018     0.919    0.000     0.081
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Create plot FOR FoxNews
x_vals_Fox = sentiments_Fox_pd["Tweets Ago"]
y_vals_Fox = sentiments_Fox_pd["Compound"]

# %%
#Scatter Plot for All

size=150
fig = plt.figure(figsize=(10, 8))

BBC_plot = plt.scatter(x_vals_BBC, y_vals_BBC, s=size, marker="o", facecolors="lightblue", edgecolors="black", label="BBC", alpha = 0.75, linewidth=1.25)

CBS_plot = plt.scatter(x_vals_CBS, y_vals_CBS, s=size, marker="o", facecolors="green", edgecolors="black", label="CBS", alpha = 0.75, linewidth=1.25)

CNN_plot = plt.scatter(x_vals_CNN, y_vals_CNN, s=size, marker="o", facecolors="red", edgecolors="black", label="CNN", alpha = 0.75, linewidth=1.25)

Fox_plot = plt.scatter(x_vals_Fox, y_vals_Fox, s=size, marker="o", facecolors="blue", edgecolors="black", label="Fox", alpha = 0.75, linewidth=1.25)

NT_plot = plt.scatter(x_vals_NT, y_vals_NT, s=size, marker="o", facecolors="yellow", edgecolors="black", label="NYTimes", alpha = 0.75, linewidth=1.25)

# Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Media Tweets ({now})")
plt.xlabel("Tweet Polarity")
plt.ylabel("Tweets Ago")
plt.xlim([105,-5]) #Bonus



# Create a legend
# Set our legend to where the chart thinks is best
lgnd = plt.legend(handles=[BBC_plot, CBS_plot, CNN_plot, Fox_plot, NT_plot], loc='upper left', bbox_to_anchor=(1, 0.5))


# Incorporate a text label regarding circle size
textstr = 'Media Source:'
plt.text(-6, 0.01, textstr, fontsize=13)

#add grid

plt.grid(True) 

# Save Figure
plt.savefig("../sentiment_scatter.png")

plt.show()

# %%
#Bar Graph

fig = plt.figure(figsize=(10, 8))

channel_list  = ["BBC", "CBS", "CNN", "Fox", "NT"]
channel_compound = []

compound_BBC =  sentiments_BBC_pd["Compound"].mean()
channel_compound.append(compound_BBC)

compound_CBS = sentiments_CBS_pd["Compound"].mean()
channel_compound.append(compound_CBS)

compound_CNN = sentiments_CNN_pd["Compound"].mean()
channel_compound.append(compound_CNN)

compound_Fox = sentiments_Fox_pd["Compound"].mean()
channel_compound.append(compound_Fox)

compound_NT =  sentiments_NT_pd["Compound"].mean()
channel_compound.append(compound_NT)

colors = ['lightskyblue', 'green', 'red', 'blue', 'yellow']


#BBC_bar = plt.bar("BBC", compound_BBC, width=1.0, color='lightskyblue', edgecolor="black", linewidth="0.75", align="center")
#CBS_bar = plt.bar("CBS", compound_CBS, width=1.0, color='green', edgecolor="black", linewidth="0.75", align="center")
#CNN_bar = plt.bar("CNN", compound_CNN, width=1.0, color='red', edgecolor="black", linewidth="0.75", align="center")
#Fox_bar = plt.bar("Fox", compound_Fox, width=1.0, color='blue', edgecolor="black", linewidth="0.75", align="center")
#NT_bar = plt.bar("NT", compound_NT, width=1.0, color='yellow', edgecolor="black", linewidth="0.75", align="center")

x_axis = np.arange(0, len(channel_list))
tick_locations = []
for i in x_axis:
    plt.bar(channel_list[i], channel_compound[i], width=1.0, color=colors[i], edgecolor="black", linewidth="0.75", align="center")

now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Overall Media Based on Tweeter ({now})")
plt.xlabel("Tweet Polarity")
plt.ylim(min(channel_compound) - 0.1, max(channel_compound) + 0.1)

plt.ylabel('Tweet Polarity')


plt.grid(False)

# Save Figure
plt.savefig("../sentiment_bar.png")

plt.show()
